# %%
import json
import os

# %%
label_path = "data/geotiffs/hold/labels/"

# %%
jsons = [os.path.join(label_path, file) for file in os.listdir(label_path) if file.endswith(".json")]

# %%
jsons
# Out:
# ['data/geotiffs/hold/labels/midwest-flooding_00000312_post_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-florence_00000258_post_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-harvey_00000188_pre_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-michael_00000148_post_disaster.json',
#  'data/geotiffs/hold/labels/mexico-earthquake_00000045_pre_disaster.json',
#  'data/geotiffs/hold/labels/santa-rosa-wildfire_00000104_pre_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-florence_00000098_pre_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-florence_00000206_pre_disaster.json',
#  'data/geotiffs/hold/labels/mexico-earthquake_00000149_pre_disaster.json',
#  'data/geotiffs/hold/labels/hurricane-harvey_00000121_post_disaster.json',
#  'data/geotiffs/hold/labels/santa-rosa-wildfire_00000218_post_disaster.json',
#  'data/geotiffs/hold/labels/socal-fire_00000712_post_disaster.json',
# ...

# %%
import json

with open(jsons[0], 'r') as file:
    data = json.load(file)

# Print the data
print(data)
# Out:
# {'features': {'lng_lat': [{'properties': {'feature_type': 'building', 'subtype': 'destroyed', 'uid': '5678e9cd-79a3-4321-a549-b3364e54ce52'}, 'wkt': 'POLYGON ((-96.29874054922256 36.15640457070931, -96.29884655890987 36.15650144367422, -96.29870531253304 36.15659564219323, -96.29859930290827 36.15649876910641, -96.29874054922256 36.15640457070931))'}, {'properties': {'feature_type': 'building', 'subtype': 'no-damage', 'uid': '03f71d99-4a5f-4786-b309-31fca700b57c'}, 'wkt': 'POLYGON ((-96.29869643129088 36.15635582212646, -96.29858552489134 36.15624496542392, -96.29846891956814 36.15614349241459, -96.29854220404587 36.15609718015811, -96.29851807765807 36.15606901827459, -96.29856781878794 36.15603580414375, -96.29858673308918 36.15605312576819, -96.29866925839883 36.15599868068338, -96.29870467547211 36.15603382098831, -96.29871936934002 36.15605579149996, -96.29865442493492 36.15610671410095, -96.29869024147256 36.15614290396401, -96.29870240236815 36.15613618281078, -96.298719921764
# ...
